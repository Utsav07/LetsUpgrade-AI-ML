# %%
import pandas as pd
dataset = pd.read_csv('general_data.csv')

# %%
dataset.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dataset["Attrition"] = pd.get_dummies(dataset["Attrition"])
dataset["BusinessTravel"] = pd.get_dummies(dataset["BusinessTravel"])
dataset["Department"] = pd.get_dummies(dataset["Department"])
dataset["EducationField"] = pd.get_dummies(dataset["EducationField"])
dataset["Gender"] = pd.get_dummies(dataset["Gender"])

# %%
dataset.head()
# Out:
#    Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0   51          0               0           0                 6          2
# 1   31          1               0           0                10          1
# 2   32          0               0           0                17          4
# 3   38          0               1           0                 2          5
# 4   32          0               0           0                10          1
#
#    EducationField  EmployeeCount  EmployeeID  Gender  ...  NumCompaniesWorked  \
# 0               0              1           1       1  ...                 1.0
# 1               0              1           2       1  ...                 0.0
# 2               0              1           3       0  ...                 1.0
# 3               0              1           4       0  ...                 3.0
# 4               0              1           5       0  ...                 4.0
#
# ...

# %%
dataset = dataset.dropna()

# %%
dataset
# Out:
#       Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0      51          0               0           0                 6          2
# 1      31          1               0           0                10          1
# 2      32          0               0           0                17          4
# 3      38          0               1           0                 2          5
# 4      32          0               0           0                10          1
# ...   ...        ...             ...         ...               ...        ...
# 4404   29          0               0           0                 4          3
# 4405   42          0               0           0                 5          4
# 4406   29          0               0           0                 2          4
# 4407   25          0               0           0                25          2
# 4408   42          0               0           0                18          2
#
# ...

# %%
from scipy.stats import pearsonr

# %%
def Hypothesis_decision(p):
    if p > 0.05:
        print("Null hypothesis is accepted!")
    else:
        print("Null hypothesis is rejected!")

# %%
stats, p = pearsonr(dataset.Attrition, dataset.Age)
print(stats, p)
Hypothesis_decision(p)
# Out:
# -0.1583986795409671 5.1265982193780794e-26
# Null hypothesis is rejected!

# %%
dataset.corr()
# Out:
#                               Age  Attrition  BusinessTravel  Department  \
# Age                      1.000000  -0.158399       -0.011885   -0.006246
# Attrition               -0.158399   1.000000       -0.073961    0.076559
# BusinessTravel          -0.011885  -0.073961        1.000000   -0.037708
# Department              -0.006246   0.076559       -0.037708    1.000000
# DistanceFromHome         0.007376  -0.009449       -0.025666   -0.023713
# Education               -0.033900  -0.017106       -0.006426    0.014752
# EducationField          -0.048261   0.088746       -0.029139    0.645885
# EmployeeCount                 NaN        NaN             NaN         NaN
# EmployeeID               0.008105  -0.004621        0.002899    0.020478
# Gender                   0.040625  -0.018396       -0.040775   -0.009070
# JobLevel                -0.001137  -0.012382       -0.041291    0.039865
# MonthlyIncome           -0.045163  -0.030160        0.059282   -0.031176
# ...

# %%
import seaborn as sns
sns.heatmap(dataset.corr(), cmap='coolwarm')

# %%
stats, p = pearsonr(dataset.YearsAtCompany, dataset.Attrition)
print(stats, p)
Hypothesis_decision(p)
# Out:
# -0.1330026184252154 9.476118084836507e-19
# Null hypothesis is rejected!

# %%
stats, p = pearsonr(dataset.Gender, dataset.Attrition)
print(stats, p)
Hypothesis_decision(p)
# Out:
# -0.01839642519444091 0.22339966086831062
# Null hypothesis is accepted!

# %%
stats, p = pearsonr(dataset.Department, dataset.Attrition)
print(stats, p)
Hypothesis_decision(p)
# Out:
# 0.0765587865532527 3.8966365695624444e-07
# Null hypothesis is rejected!

# %%
stats, p = pearsonr(dataset.Education, dataset.Attrition)
print(stats, p)
Hypothesis_decision(p)
# Out:
# -0.017106307050278723 0.25757539308157945
# Null hypothesis is accepted!

# %%
stats, p = pearsonr(dataset.EducationField, dataset.Attrition)
print(stats, p)
Hypothesis_decision(p)
# Out:
# 0.08874559615384177 3.990155946140969e-09
# Null hypothesis is rejected!

# %%
stats, p = pearsonr(dataset.DistanceFromHome, dataset.Attrition)
print(stats, p)
Hypothesis_decision(p)
# Out:
# -0.009448638515156248 0.5317715668019558
# Null hypothesis is accepted!

# %%
stats, p = pearsonr(dataset.YearsAtCompany, dataset.Attrition)
print(stats, p)
Hypothesis_decision(p)
# Out:
# -0.1330026184252154 9.476118084836507e-19
# Null hypothesis is rejected!

# %%
stats, p = pearsonr(dataset.MonthlyIncome, dataset.Attrition)
print(stats, p)
Hypothesis_decision(p)
# Out:
# -0.030160293808460664 0.045890862744719166
# Null hypothesis is rejected!

# %%
from scipy.stats import mannwhitneyu
a2 = dataset.DistanceFromHome
a1 = dataset.Attrition
stat,p = mannwhitneyu(a1, a2)
print(stat, p)
Hypothesis_decision(p)
# Out:
# 219255.0 0.0
# Null hypothesis is rejected!

# %%
from scipy.stats import mannwhitneyu
a1 = dataset.TotalWorkingYears
a2 = dataset.Attrition
stat,p = mannwhitneyu(a1, a2)
print(stat, p)
Hypothesis_decision(p)
# Out:
# 166344.5 0.0
# Null hypothesis is rejected!

# %%
from scipy.stats import mannwhitneyu
a1 = dataset.YearsWithCurrManager
a2 = dataset.Attrition
stat,p = mannwhitneyu(a1, a2)
print(stat, p)
Hypothesis_decision(p)
# Out:
# 2069034.5 0.0
# Null hypothesis is rejected!
